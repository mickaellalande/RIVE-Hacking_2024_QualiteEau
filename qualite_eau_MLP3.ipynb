# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError
import tensorflow.keras.backend as K
import tensorflow as tf # Machine learning

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import proplot as pplt # New plot library (https://proplot.readthedocs.io/en/latest/)
pplt.rc['savefig.dpi'] = 300 # 1200 is too big! #https://proplot.readthedocs.io/en/latest/basics.html#Creating-figures
from scipy import stats


# Chargement des librairies + données
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# 2024-01-12 17:24:24.649623: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_excel('../merged_data.xlsx')
df
# Out:
#           Red     Green      Blue  superficie_totale_drainee  agricole  \
# 0    0.266133  0.338741  0.395126                        NaN       NaN
# 1    0.230186  0.370447  0.399367                    705.492      0.05
# 2    0.239546  0.366269  0.394185                    248.312      0.05
# 3    0.218447  0.370770  0.410784                     99.322      6.15
# 4    0.242465  0.364553  0.392982                        NaN      0.18
# ..        ...       ...       ...                        ...       ...
# 502  0.291763  0.340796  0.367441                        NaN      5.85
# 503  0.254787  0.365533  0.379680                        NaN       NaN
# 504  0.259204  0.359909  0.380888                        NaN       NaN
# 505  0.256408  0.364179  0.379413                        NaN       NaN
# 506  0.249774  0.353461  0.396766                        NaN       NaN
#
#      forestier  humide  aquatique  anthropique  coupe_regenaration  ...  \
# 0          NaN     NaN        NaN          NaN                 NaN  ...
# 1        96.21    0.71       0.41         0.28                2.27  ...
# 2        89.15    0.49       0.59         0.86                8.85  ...
# 3        74.59   10.43       1.24         4.54                3.05  ...
# 4        91.07    1.88       0.52         0.09                6.08  ...
# ..         ...     ...        ...          ...                 ...  ...
# 502      42.51   30.47       9.63         3.42                7.88  ...
# 503        NaN     NaN        NaN          NaN                 NaN  ...
# 504        NaN     NaN        NaN          NaN                 NaN  ...
# 505        NaN     NaN        NaN          NaN                 NaN  ...
# 506        NaN     NaN        NaN          NaN                 NaN  ...
#
#       p_t_per        ph      pheo          ss       temp       turb  \
# 0    0.329250       NaN  3.015000  814.750000        NaN        NaN
# 1    0.003000  8.225000  0.097500    1.250000  14.500000   1.100000
# 2    0.002250  8.175000  0.232500    2.625000  15.000000   1.000000
# 3    0.004250  8.125000  0.702500    3.500000  13.250000   1.475000
# 4    0.002333  8.133333  0.116667    1.500000  13.333333   1.000000
# ..        ...       ...       ...         ...        ...        ...
# 502  0.032471  7.200000  1.370000   11.352941  17.692308  21.562500
# 503  0.130562       NaN       NaN   43.187500        NaN        NaN
# 504  0.096130  7.700000  9.442857   20.804348  19.652632  52.030435
# 505  0.067909  7.522727  2.980000   14.386364  19.766667  47.000000
# 506  0.037500       NaN       NaN   12.250000        NaN        NaN
#
#         durete      iqbp6   latitude  longitude
# 0          NaN  50.500000  46.749694 -71.299333
# 1          NaN  95.000000  48.408981 -64.516755
# 2          NaN  88.000000  48.386735 -64.601016
# 3          NaN  88.250000  48.062150 -65.164711
# 4          NaN  96.333333  48.086762 -65.447414
# ..         ...        ...        ...        ...
# 502  25.907692  60.882353  48.560392 -78.114931
# 503        NaN  14.750000  48.454972 -78.038583
# 504  72.453333   8.956522  48.659443 -79.227044
# 505  53.726667  35.181818  48.749029 -79.228012
# 506        NaN  42.750000  48.819306 -78.910723
#
# [507 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Red', 'Green', 'Blue', 'superficie_totale_drainee', 'agricole',
#        'forestier', 'humide', 'aquatique', 'anthropique', 'coupe_regenaration',
#        'sol_nu', 'non_classifie', 'cat', 'cf', 'chl_aa', 'cod', 'cond', 'mg',
#        'nh3', 'nox', 'ntot', 'p_t_per', 'ph', 'pheo', 'ss', 'temp', 'turb',
#        'durete', 'iqbp6', 'latitude', 'longitude'],
#       dtype='object')

# %%
df.dropna()
# Out:
#           Red     Green      Blue  superficie_totale_drainee  agricole  \
# 7    0.236677  0.363164  0.400159                    325.995      0.24
# 8    0.283264  0.339041  0.377695                    565.644     15.14
# 10   0.282846  0.339616  0.377538                    456.652     16.87
# 14   0.225026  0.366269  0.408705                    258.525      4.35
# 15   0.275870  0.338291  0.385839                    323.355      6.05
# ..        ...       ...       ...                        ...       ...
# 474  0.263181  0.363113  0.373706                    217.504     36.72
# 475  0.233956  0.345644  0.420400                    424.771     13.61
# 485  0.270539  0.342693  0.386768                    803.085      0.33
# 492  0.236798  0.358321  0.404881                    115.937     16.26
# 499  0.228961  0.360331  0.410708                    366.375      0.00
#
#      forestier  humide  aquatique  anthropique  coupe_regenaration  ...  \
# 7        94.06    0.41       0.21         0.59                4.50  ...
# 8        63.48    7.28       7.93         2.31                3.85  ...
# 10       68.86    5.96       1.17         1.96                5.16  ...
# 14       82.01    3.12       4.61         2.56                3.35  ...
# 15       80.42    3.56       3.87         2.90                3.19  ...
# ..         ...     ...        ...          ...                 ...  ...
# 474      25.79   27.83       2.79         3.21                3.12  ...
# 475      56.85   19.64       3.17         2.14                4.15  ...
# 485      80.16    3.73       7.55         0.79                6.84  ...
# 492      71.08    2.52       2.72         3.92                3.31  ...
# 499      38.42   36.30       8.95         2.68               13.62  ...
#
#       p_t_per        ph      pheo         ss       temp       turb     durete  \
# 7    0.002303  8.112121  0.305172   2.106061  12.293333   1.312121  83.325000
# 8    0.007083  8.100000  0.684375   2.388889  16.394118   1.650000  92.175000
# 10   0.005306  8.158333  0.703750   2.666667  14.650000   1.438889  99.325000
# 14   0.005158  7.836842  0.640667   1.736842  18.312500   1.126316  54.850000
# 15   0.032250  7.950000  1.131250   4.800000  19.929412   4.135000  66.733333
# ..        ...       ...       ...        ...        ...        ...        ...
# 474  0.036880  7.520000  1.734167  18.640000  13.536842   9.472000  28.646154
# 475  0.035667  7.525926  1.864167  14.537037  16.460870  10.237037  25.053333
# 485  0.004207  7.122414  0.286667   1.672414  17.409259   1.210345   8.213636
# 492  0.037500  7.708621  1.440000  15.741379  15.268519  12.582759  45.950000
# 499  0.020571  6.690476  1.582500  13.380952  18.252941   4.347619  49.646154
#
#          iqbp6   latitude  longitude
# 7    92.606061  48.126467 -66.468117
# 8    82.944444  48.463999 -67.429503
# 10   82.250000  48.462613 -67.430269
# 14   85.000000  47.578738 -68.921726
# 15   69.450000  47.676496 -68.875398
# ..         ...        ...        ...
# 474  45.040000  48.642188 -71.670950
# 475  60.370370  48.478756 -71.313556
# 485  94.931034  48.344670 -69.408570
# 492  60.086207  48.187857 -69.698605
# 499  78.714286  48.094307 -77.657784
#
# [135 rows x 31 columns]

# %%
target = 'cod'
data2 = df.copy()
data2 = data2.drop(columns=['cat', 'cf', 'chl_aa', 'cond', 'mg',
       'nh3', 'nox', 'ntot', 'p_t_per', 'ph', 'pheo', 'ss', 'temp', 'turb',
       'durete', 'iqbp6', 'latitude', 'longitude'])
# data2 = data2.dropna(subset=[target])
data2 = data2.dropna()
data2
# Out:
#           Red     Green      Blue  superficie_totale_drainee  agricole  \
# 1    0.230186  0.370447  0.399367                    705.492      0.05
# 2    0.239546  0.366269  0.394185                    248.312      0.05
# 3    0.218447  0.370770  0.410784                     99.322      6.15
# 7    0.236677  0.363164  0.400159                    325.995      0.24
# 8    0.283264  0.339041  0.377695                    565.644     15.14
# ..        ...       ...       ...                        ...       ...
# 485  0.270539  0.342693  0.386768                    803.085      0.33
# 492  0.236798  0.358321  0.404881                    115.937     16.26
# 498  0.247511  0.355688  0.396801                    170.611      0.00
# 499  0.228961  0.360331  0.410708                    366.375      0.00
# 500  0.251244  0.356411  0.392345                    676.583      1.69
#
#      forestier  humide  aquatique  anthropique  coupe_regenaration  sol_nu  \
# 1        96.21    0.71       0.41         0.28                2.27    0.06
# 2        89.15    0.49       0.59         0.86                8.85    0.01
# 3        74.59   10.43       1.24         4.54                3.05    0.00
# 7        94.06    0.41       0.21         0.59                4.50    0.00
# 8        63.48    7.28       7.93         2.31                3.85    0.00
# ..         ...     ...        ...          ...                 ...     ...
# 485      80.16    3.73       7.55         0.79                6.84    0.57
# 492      71.08    2.52       2.72         3.92                3.31    0.17
# 498      47.96   30.71       3.05         1.82               16.45    0.00
# 499      38.42   36.30       8.95         2.68               13.62    0.03
# 500      36.46   37.42       6.17         4.39               13.74    0.12
#
#      non_classifie        cod
# 1             0.00   1.250000
# 2             0.01   1.100000
# 3             0.00   2.500000
# 7             0.00   0.766667
# 8             0.00   4.258333
# ..             ...        ...
# 485           0.03   4.146552
# 492           0.02   3.982759
# 498           0.00  22.295238
# 499           0.00  18.304762
# 500           0.00  16.971429
#
# [171 rows x 13 columns]

# %%
seed = np.random.seed(2024)
train_data, val_data = train_test_split(data2, test_size=0.25, random_state=seed)

# %%
train_data
# Out:
#           Red     Green      Blue  superficie_totale_drainee  agricole  \
# 8    0.283264  0.339041  0.377695                    565.644     15.14
# 9    0.248626  0.356017  0.395356                     39.028     23.37
# 34   0.271509  0.352941  0.375550                    453.918     23.26
# 204  0.276549  0.336626  0.386825                     94.693     74.22
# 178  0.237510  0.367158  0.395332                    146.191     16.04
# ..        ...       ...       ...                        ...       ...
# 91   0.231234  0.371915  0.396851                    634.524     19.34
# 67   0.245192  0.368698  0.386110                    732.570     32.12
# 362  0.308568  0.327285  0.364147                    526.680      5.68
# 217  0.231898  0.365037  0.403065                    112.152     35.90
# 387  0.283273  0.347517  0.369210                     26.834     57.28
#
# 243           0.00   5.085714
# 102           0.01  10.070000
# 326           0.02   5.364706
# 465           0.00  19.053333
# 126           0.00   8.851064
# 38            0.00   6.405263
# 145           0.00  10.505263
# 500           0.00  16.971429
# 256           0.05   4.062069
# 84            0.00  10.723810
# 464           0.03   7.773333
# 88            0.00  11.515385
# 372           0.01   3.915000
# 182           0.00  10.011111
# 429           0.00   6.148710
# 144           0.00   4.972222
# 49            0.00   5.678947
# 187           0.00   2.900000
# 286           0.00   6.343902
# 66            0.00   9.432609
# 205           0.00   3.000000
# 225           0.00   3.944444
# 475           0.02   8.085185
# 485           0.03   4.146552
# 137           0.00   9.556818
# 468           0.01   7.285714
# 195           0.00   6.241667
# 118           0.01   5.617021
# 413           0.03   4.245714
# 120           0.00   4.270213
# 174           0.00   5.224138
# 44            0.01   9.515517
# 95            0.00   3.788889
# 177           0.01   3.927586
# 158           0.00   3.800000
# 386           0.00   2.982222
# 432           0.04   3.745161
# 212           0.00   3.976786
# 59            0.00   9.745455
# 474           0.00   5.160000
# 403           0.01   5.756250
# 163           0.00   6.713889

# %%
train_data.iloc[:, :-1] = StandardScaler().fit_transform(train_data.drop(columns=target))
val_data.iloc[:, :-1] = StandardScaler().fit_transform(val_data.drop(columns=target))

# %%
train_data
# Out:
#           Red     Green      Blue  superficie_totale_drainee  agricole  \
# 8    1.467401 -1.717873 -1.014078                   1.136185 -0.607726
# 9   -0.182327 -0.066716  0.348177                  -0.995303 -0.298406
# 34   0.907515 -0.365896 -1.179515                   0.683972 -0.302540
# 204  1.147572 -1.952799 -0.309830                  -0.769998  1.612763
# 178 -0.711752  1.016843  0.346272                  -0.561559 -0.573900
# ..        ...       ...       ...                        ...       ...
# 91  -1.010670  1.479492  0.463466                   1.414978 -0.449871
# 67  -0.345899  1.166664 -0.365021                   1.811821  0.030458
# 362  2.672583 -2.861273 -2.059075                   0.978477 -0.963274
# 217 -0.979046  0.810569  0.942721                  -0.699332  0.172527
# 387  1.467813 -0.893450 -1.668530                  -1.044658  0.976082
#
#      forestier    humide  aquatique  anthropique  coupe_regenaration  \
# 8     0.513831 -0.065359   2.318998    -0.385762            0.439923
# 9     0.491234 -0.658185  -0.077917    -0.178571            0.672995
# 34    0.368336  0.157657  -0.400654    -0.025382           -0.318337
# 204  -1.851748 -0.813449  -0.762750     1.549486           -0.750297
# 178   0.913050 -0.446461  -0.573830    -0.108038           -0.622885
# ..         ...       ...        ...          ...                 ...
# 91    0.454365 -0.450696   0.170040     0.438592           -0.200248
# 67    0.339793 -0.552323  -0.644675    -0.265635           -0.396028
# 362   0.214516 -0.292609   0.055901     2.533642           -0.215786
# 217   0.248214 -0.627132  -0.081853    -0.397884           -0.756513
# 387  -0.951821  0.420194  -0.790301    -0.068363           -0.672607
#
#        sol_nu  non_classifie       cod
# 8   -0.181788      -0.530330  4.258333
# 9   -0.181788       0.176777  6.208571
# 34  -0.116056      -0.530330  6.637931
# 204 -0.181788      -0.530330  6.041379
# 178 -0.181788      -0.530330  3.164286
# ..        ...            ...       ...
# 91  -0.089764      -0.530330  6.342308
# 67  -0.181788      -0.530330  6.573333
# 362 -0.181788       0.176777  5.417544
# 217 -0.181788      -0.530330  6.394545
# 387 -0.181788      -0.530330  5.174468
#
# [128 rows x 13 columns]

# %%
train = train_data.copy()
val = val_data.copy()

x_train = train.drop(columns=target)
x_val = val.drop(columns=target)

y_train = train[target]
y_val = val[target]

x_train_arr, y_train_arr = np.array(x_train), np.array(y_train)
x_val_arr,  y_val_arr  = np.array(x_val),  np.array(y_val)

# %%
def get_model_v1(shape):
    
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input(shape, name="InputLayer"))
    model.add(tf.keras.layers.Dense(16, activation='relu', name='Dense_n1'))
    model.add(Dropout(0.2))
    model.add(tf.keras.layers.Dense(32, activation='relu', name='Dense_n2'))
    model.add(tf.keras.layers.Dense(64, activation='relu', name='Dense_n21'))
    model.add(tf.keras.layers.Dense(32, activation='relu', name='Dense_n22'))
    model.add(Dropout(0.2))
    model.add(tf.keras.layers.Dense(16, activation='relu', name='Dense_n3'))
    
    # Output
    # The sigmoid actiavation allow to keep results between 0 and 1
    # model.add(tf.keras.layers.Dense(1, activation='sigmoid', name='Output'))
    model.add(tf.keras.layers.Dense(1, name='Output'))
    
    model.compile(optimizer = 'adam', loss = 'mse', metrics=["mae"])
    
    return model

# %%
input_size = len(x_train_arr[0])
model = get_model_v1( (input_size,) )
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_n1 (Dense)            (None, 16)                208
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  Dense_n2 (Dense)            (None, 32)                544
#
#  Dense_n21 (Dense)           (None, 64)                2112
#
#  Dense_n22 (Dense)           (None, 32)                2080
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  Dense_n3 (Dense)            (None, 16)                528
#
#  Output (Dense)              (None, 1)                 17
#
# =================================================================
# Total params: 5489 (21.44 KB)
# Trainable params: 5489 (21.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train_arr,
                    y_train_arr,
                    epochs          = 100,
                    batch_size      = 10,
                    verbose         = 1,
                    validation_data = (x_val_arr, y_val_arr),
                   )
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 12ms/step - loss: 53.0613 - mae: 6.4080 - val_loss: 53.4939 - val_mae: 6.4349
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 46.9934 - mae: 5.8864 - val_loss: 44.9178 - val_mae: 5.7357
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 33.7033 - mae: 4.7627 - val_loss: 27.2102 - val_mae: 4.0362
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 20.2346 - mae: 3.4865 - val_loss: 12.4313 - val_mae: 2.7160
# Epoch 5/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.1530 - mae: 2.7034 - val_loss: 8.8707 - val_mae: 2.4147
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 12.5793 - mae: 2.5340 - val_loss: 8.3266 - val_mae: 2.3280
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 8.4371 - mae: 2.2138 - val_loss: 7.6054 - val_mae: 2.2701
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 10.2958 - mae: 2.4326 - val_loss: 7.8038 - val_mae: 2.2884
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8883 - mae: 2.3334 - val_loss: 7.1263 - val_mae: 2.1987
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 7.6980 - mae: 2.0853 - val_loss: 6.7042 - val_mae: 2.1295
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 6.6923 - mae: 1.9931 - val_loss: 6.6822 - val_mae: 2.1242
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 6.8567 - mae: 2.0542 - val_loss: 7.0325 - val_mae: 2.1658
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss:
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 3.6328 - mae: 1.3980 - val_loss: 6.1454 - val_mae: 1.8870
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 4.5566 - mae: 1.5539 - val_loss: 5.8375 - val_mae: 1.8086
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 4.2800 - mae: 1.5595 - val_loss: 6.1395 - val_mae: 1.8860
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 4.1808 - mae: 1.4614 - val_loss: 5.9106 - val_mae: 1.8174
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 4.7577 - mae: 1.5361 - val_loss: 5.7011 - val_mae: 1.7199
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 3.5577 - mae: 1.4348 - val_loss: 5.9020 - val_mae: 1.7957
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 3.9781 - mae: 1.4574 - val_loss: 5.7926 - val_mae: 1.7405
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 4.2184 - mae: 1.4739 - val_loss: 5.9432 - val_mae: 1.7889
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 3.6780 - mae: 1.4274 - val_loss: 5.7907 - val_mae: 1.7097

# %%
fig, axs = pplt.subplots(ncols=1, nrows=1, refwidth=4, sharey=0, refaspect=1.5)

axs[0].plot(history.history['loss'], label='training')
axs[0].plot(history.history['val_loss'], label='validation')
axs[0].format(xlabel='Epoch', ylabel='Loss (MSE)')
axs[0].legend()

fig.suptitle('Learning curve COD')
fig.save('../img/learning_curve_MLP3.jpg')
# Out:
# Figure(nrows=1, ncols=1, refaspect=1.5, refwidth=4.0)

# %%
predict_train = model.predict(x_train_arr)
predict_val = model.predict(x_val_arr)
# Out:
# 4/4 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
stats.linregress(predict_train.squeeze(), y_train_arr.squeeze())
# Out:
# LinregressResult(slope=1.0767300898772798, intercept=-0.33992108717886005, rvalue=0.912311222945267, pvalue=1.0807670851176421e-50, stderr=0.043055620589443525, intercept_stderr=0.30252345545538983)

# %%
stats.linregress(predict_val.squeeze(), y_val_arr.squeeze())
# Out:
# LinregressResult(slope=0.8714315055313819, intercept=0.8329679509607661, rvalue=0.7293082753499159, pvalue=2.9081550268159647e-08, stderr=0.12767441801347462, intercept_stderr=0.9454683197673136)

# %%
fig, axs = pplt.subplots(ncols=2, share=0)

axs[0].scatter(predict_train, y_train_arr)
axs[1].scatter(predict_val, y_val_arr)

# Make linear trend for models values and compute pearsonr
reg_train = stats.linregress(predict_train.squeeze(), y_train_arr.squeeze())
reg_val = stats.linregress(predict_val.squeeze(), y_val_arr.squeeze())

x = pplt.arange(0, predict_train.max())
y = reg_train.slope*x + reg_train.intercept
axs[0].plot(x, y, 'k-', linewidth=0.8, alpha=0.8)
axs[0].format(lrtitle='$r^2$ = ' + str(round(reg_train.rvalue**2, 2)) + ' (%.2f)' % round(reg_train.pvalue, 2))

x = pplt.arange(0, predict_val.max())
y = reg_train.slope*x + reg_val.intercept
axs[1].plot(x, y, 'k-', linewidth=0.8, alpha=0.8)
axs[1].format(lrtitle='$r^2$ = ' + str(round(reg_val.rvalue**2, 2)) + ' (%.2f)' % round(reg_val.pvalue, 2))

axs[0].format(title='Training (128)', xlabel='Predicted COD (mg/L)', ylabel='Observed COD (mg/L)')
axs[1].format(title='Validation (43)', xlabel='Predicted COD (mg/L)', ylabel='Observed COD (mg/L)')

fig.suptitle('Carbone organique dissout (MLP)')
fig.save('../img/corr_MLP3.jpg')
# Out:
# Figure(nrows=1, ncols=2, refwidth=2.5)
